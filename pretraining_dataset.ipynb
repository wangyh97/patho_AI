# %%
import glob
import os
import pathlib
from pathlib import Path

import pandas as pd

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
df = pd.read_csv("dir_uuid.csv")
uuid = df["dir_uuid"]  # 获取符合条件的uuid

slides = glob.glob(f"/mnt/wangyh/TCGA_bladder/TCGA_bladder/*/*.svs")
wsi_path = []
for i in slides:
    id = os.path.split(Path(i).parent)[1]
    if id in uuid.values:
        wsi_path.append(i)

# print(wsi_path)
# print(len(wsi_path))
pd.Series(wsi_path).to_csv('wsi_path_for_pretraining.csv')

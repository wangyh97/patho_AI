# %%
import os
import glob
import pandas as pd

# %%
slides = glob.glob(f"/mnt/wangyh/TCGA_bladder/TCGA_bladder/*/*.svs")

# %%
os.getcwd()
# Out:
# '/home/wangyh/uro_biomarker/patho_AI'

# %%
pd.DataFrame(slides).to_csv("slides.csv")

# %%
len(slides)
# Out:
# 418

# %%
slides
# Out:
# ['/mnt/wangyh/TCGA_bladder/TCGA_bladder/66c9a30b-2303-47fa-abe5-85f8ee3abbaf/TCGA-G2-AA3B-01Z-00-DX5.57084980-934B-4A4A-A720-24FA2E9E0CB2.svs',
#  '/mnt/wangyh/TCGA_bladder/TCGA_bladder/474e93f2-2ee8-478d-9a87-ab561286535f/TCGA-FD-A6TG-01Z-00-DX1.C49D520E-3589-4623-9BBE-9676BAC83A8F.svs',
#  '/mnt/wangyh/TCGA_bladder/TCGA_bladder/9cf7130c-f381-45df-ae0a-c14017637537/TCGA-GU-A766-01Z-00-DX1.72BD6744-E817-4B15-BF58-64BDBC1943FF.svs',
#  '/mnt/wangyh/TCGA_bladder/TCGA_bladder/1f24af21-9bb4-409f-8bbc-5a0e56d777ab/TCGA-UY-A9PE-01Z-00-DX1.19205347-9969-475E-9293-E99D4833E462.svs',
#  '/mnt/wangyh/TCGA_bladder/TCGA_bladder/0fcdc140-1ee5-4c7a-a210-f2b4990690af/TCGA-XF-A9SV-01Z-00-DX1.2ACAA181-2EFA-4E63-B692-D968BCC56031.svs',
#  '/mnt/wangyh/TCGA_bladder/TCGA_bladder/28a0ced3-7a6e-45cc-b47c-88686d5816ec/TCGA-S5-AA26-01Z-00-DX1.10D28D0C-D537-485E-A371-E3C60ED66FE7.svs',
# ...
